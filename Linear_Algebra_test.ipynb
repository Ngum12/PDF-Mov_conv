# %% [markdown]
# <a href="https://colab.research.google.com/github/Ngum12/PDF-Mov_conv/blob/main/Linear_Algebra_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lets try out Matrix computation on actual codes
# **Make a Copy Please and try!!**

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
A = np.array([[1,2],
     [4, 5]])

S = np.array([9,7])

#Ax = S
#x = S*inverse(A)

X = np.linalg.solve(A,S)

print(X)
# Out:
# [-10.33333333   9.66666667]

# %% [markdown]
# Using python and numpy, assume going to silicon valley each student pays 300.60 and each coach pays 1000.60 for a total of 13415.6 and when coming back a student pays 500.25 and a coach pays 120.85 (yes the game’s Rigged!! )     for a total of 18777.6

# %% [markdown]
# ![Screenshot from 2023-09-04 12-19-32.png](data:image/png;base64,...)

# %%
#...I do not have to import numpy again??? why

Price = [[300.60, 500.25],
        [1000.60, 120.85]
        ]#TO DO .....

Total = [9412.8, 18977.6]#TO DO .....

no_of_students, number_of_coaches = #To do......
print(f'the number of studnets who went to silicon valley is: {no_of_students}')
print(f'the number of Coaches who went to silicon valley is: {number_of_coaches}')
# Out:
# the number of studnets who went to silicon valley is: 18.0
# the number of Coaches who went to silicon valley is: 7.999999999999999

# %%
#...Ngum Dieudonne's solution
import numpy as np

Price = [[300.60, 500.25],
        [1000.60, 120.85]
        ]


Total = [9412.8, 18977.6]

no_of_students, number_of_coaches = np.linalg.solve(Price, Total)
print(f'the number of studnets who went to silicon valley is: {no_of_students}')
print(f'the number of Coaches who went to silicon valley is: {number_of_coaches}')
# Out:
# the number of studnets who went to silicon valley is: 18.0
# the number of Coaches who went to silicon valley is: 7.999999999999999

# %% [markdown]
# **What does matrix multiplication without code look like?**:

# %%
#...Marvin's Solution

Price = [[300.60, 500.25],
        [1000.60, 120.85]
        ]#TO DO .....

Total = [9412.8, 18977.6] #TO DO .....

no_of_students, number_of_coaches = #To do......
print(f'the number of studnets who went to silicon valley is: {no_of_students}')
print(f'the number of Coaches who went to silicon valley is: {number_of_coaches}')

# %%
#...Josaine's Solution

Price = [[300.60, 500.25],
        [1000.60, 120.85]
        ]#TO DO .....

Total = [9412.8, 18977.6] #TO DO .....

no_of_students, number_of_coaches = #To do......
print(f'the number of studnets who went to silicon valley is: {no_of_students}')
print(f'the number of Coaches who went to silicon valley is: {number_of_coaches}')
# Out:
#   File "<ipython-input-1-2a4a44919fb4>", line 9
#     no_of_students, number_of_coaches = #To do......
#                                         ^
# SyntaxError: invalid syntax

# %%
# ...Eliane's solution
import numpy as np

Price = np.array([[300.60, 500.25],
        [1000.60, 120.85]
        ])

Total = np.array([9412.8, 18977.6])

no_of_students, number_of_coaches = np.linalg.solve(Price, Total)

# no_of_students = np.linalg.solve(Price, Total)
# no_of_coaches = np.linalg.solve(Price, Total)
print(f'the number of students who went to silicon valley is: {no_of_students}')
print(f'the number of Coaches who went to silicon valley is: {number_of_coaches}')
# Out:
# the number of students who went to silicon valley is: 18.0
# the number of Coaches who went to silicon valley is: 7.999999999999999

# %%
#...Raini's Solution
import numpy as np

Price = np.array([[300.60, 500.25],
        [1000.60, 120.85]]
        )

Total = np.array([9412.8, 18977.6])
# prices (num_of_std&coaches) = total
# num_of_std&coaches = total * inverse(prices)

no_of_students, number_of_coaches = np.linalg.solve(Price, Total)
print(f'the number of studnets who went to silicon valley is: {no_of_students}')
print(f'the number of Coaches who went to silicon valley is: {number_of_coaches}')
# Out:
# the number of studnets who went to silicon valley is: 18.0
# the number of Coaches who went to silicon valley is: 7.999999999999999

# %%
#...Christian's solution

# %%
#...Merveille's solution
import numpy as np
Price = np.array([[300.60, 500.25],
        [1000.60, 120.85]
        ])#TO DO .....

Total = np.array([9412.8, 18977.6])#TO DO .....
solution = np.linalg.solve(Price, Total)
no_of_students, number_of_coaches = solution
print(f'the number of studnets who went to silicon valley is: {no_of_students}')
print(f'the number of Coaches who went to silicon valley is: {number_of_coaches}')
# Out:
# the number of studnets who went to silicon valley is: 18.0
# the number of Coaches who went to silicon valley is: 7.999999999999999

# %%
#...Marion's Solution
import numpy as np

Price = [[300.60, 500.25],
        [1000.60, 120.85]]

Total = [9412.8, 18977.6]

final_answer = np.linalg.solve(Price, Total)
no_of_students, number_of_coaches = final_answer
print(f'the number of students who went to silicon valley is: {no_of_students}')
print(f'the number of Coaches who went to silicon valley is: {number_of_coaches}')
# Out:
# the number of students who went to silicon valley is: 18.0
# the number of Coaches who went to silicon valley is: 7.999999999999999
